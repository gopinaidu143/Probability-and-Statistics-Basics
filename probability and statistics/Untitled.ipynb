# %%
d={1:2,2:3,3:4}
sum=0
for i in d.keys():
    sum=sum+i
print(sum)
# Out:
# 6

# %%
import matplotlib.pyplot as plt
data=[5,10,15]
values=[13,10.5,16]
plt.plot(data,values)
plt.show()

# %%
import matplotlib.pyplot as plt
month=["jan","feb","mar","april","may"]
temperature=[17.5,20,35,42,48]
plt.plot(month,temperature)
plt.xlabel("month")
plt.ylabel("temperature")
plt.title("month vs temp")
plt.grid(True)
#plt.yticks(temperature)
#plt.xticks(month)
plt.show()
